# %% [markdown]
# ### Part II
# ### **<u>Objective</u>**:
#
# Manipulate data and do on-hot encoding and get a new data set to work on.

# %%
from functions import read_csv, get_plots
import numpy as np

## Although we repeated this step in part II, it was necessary to visualize to make sure all the major steps should be taken.
## In this step we are going to do one hot encoding on all columns because they are all categorical.
df = read_csv("mushrooms.csv")
get_plots(df)

# %% [markdown]
# First step, getting rid of column 'veil-type', since it doesn't have a major impact.

# %%
df = df.drop(columns=['veil-type'])
df = df.drop(columns= 'stalk-root')

# %% [markdown]
# Successfully dropped the column.

# %%
df_test = df.copy()

# %%
df_test.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# ...

# %% [markdown]
# e = 0, p = 1

# %%
##df_test.iloc[:, 0] = np.where(df_test.iloc[:, 0] == 'e', 0, 1)

# %%
df_test.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-above-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# 0                        s                      w                      w
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math

# Assume 'class' is your target column
target_col = 'class'

# Get all feature columns except the target
feature_cols = [col for col in df_test.columns if col != target_col]

# Number of plots per row
plots_per_row = 5
total_plots = len(feature_cols)
rows = math.ceil(total_plots / plots_per_row)

# Set figure size based on number of rows and columns
plt.figure(figsize=(plots_per_row * 4, rows * 4))

for i, col in enumerate(feature_cols):
    # Group and unstack to prepare for bar plot
    counts = df_test.groupby([col, target_col]).size().unstack(fill_value=0)

    # Plot
    plt.subplot(rows, plots_per_row, i + 1)
    counts.plot(kind='bar', ax=plt.gca(), title=col)
    plt.xlabel(col)
    plt.ylabel('Count')

plt.tight_layout()
plt.show()
